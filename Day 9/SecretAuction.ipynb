# %% [markdown]
# # Dictionaries, Nesting and The secret auction

# %%
programming_dictionary = {"Bug":"definitaion3", "Function":"defination2", 1:"defination1"}

# %%
print(programming_dictionary["Bug"])
# Out:
# definitaion3

# %%
programming_dictionary["Loop"] = "defination4"
print(programming_dictionary)
# Out:
# {'Bug': 'definitaion3', 'Function': 'defination2', 1: 'defination1', 'Loop': 'defination4'}

# %%
progaming_dictionary = {}

# %%
print(progaming_dictionary)
# Out:
# {}

# %%
for key in programming_dictionary:
  print(key)
  print(programming_dictionary[key])
# Out:
# Bug
# definitaion3
# Function
# defination2
# 1
# defination1
# Loop
# defination4

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

student_grades ={}

for key in student_scores:
    if 91 <= student_scores[key] <= 100:
        student_grades[key] = "Outstanding"
    elif  81 <= student_scores[key] <= 90:
      student_grades[key] = "Exceeds Expectations"
    elif 71 <= student_scores[key] <= 80:
      student_grades[key] = "Acceptable"
    else:
      student_grades[key] = "Fail"
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
capjitals = {"France": "Paris", "Germany": "Berlin"}
travel_log = {"France": ["Paris", "Lille", "Dijon"], "Germany": ["Berlin", "Hamburg", "Stuttgart"]}
print(travel_log['France'][1])
# Out:
# Lille

# %%
print(travel_log)
# Out:
# {'France': {'numberofcities': 8, 'cities_visited': ['Paris', 'Lille', 'Dijon']}, 'Germany': {'numberofcities': 5, 'cities_visited': ['Berlin', 'Hamburg', 'Stuttgart']}}

# %%
nested_list = ["A", "B", ["C", "D", ["E", "F", "G"]]]
print(nested_list[2][1])
print(nested_list)
# Out:
# D
# ['A', 'B', ['C', 'D', ['E', 'F', 'G']]]

# %%
travel_log = {"France":
              {"numberofcities":8, "cities_visited": ["Paris", "Lille", "Dijon"]},
              "Germany":
              {"numberofcities":5, "cities_visited": ["Berlin", "Hamburg", "Stuttgart"]}
              }
print(travel_log["France"]['cities_visited'][1])
# Out:
# Lille

# %%
name = input("What is youe name?: ")
price = int(input("What is your bid?: $"))

bids = {}

bids[name] = price

should_continue = input("Are there any other bidders? Type 'yes' or 'no'.\n")
while should_continue == "yes":

# %%
from IPython.display import clear_output

def find_highest_bidder(bidding_record):
  highest_bid = 0
  winner = ""
  for bidder in bidding_record:
    bid_amount = bidding_record[bidder]
    if bid_amount > highest_bid:
      highest_bid = bid_amount
      winner = bidder
  print(f"The winner is {winner} with a bid of ${highest_bid}.")

bids = {}
continue_bidding = True

while continue_bidding:
  name = input("What is youe name?: ")
  price = int(input("What is your bid?: $"))

  bids[name] = price
  should_continue = input("Are there any other bidders? Type 'yes' or 'no'.\n").lower()
  clear_output(wait=True)
  if should_continue == 'yes':
    continue_bidding = True

  else:
    continue_bidding = False
    find_highest_bidder(bids)
# Out:
# The winner is jhdsfjh with a bid of $8754.
